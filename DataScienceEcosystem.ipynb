# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.
# We will cover the following topics:
# * languages
# * libraries
# * science tools
# * arithmetic expressions
#
# Here we go below...

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# * SQL
# * Python
# * R

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# * NumPy
# * Pandas
# * ggplot

# %% [markdown]
# Tools Table:
# | Data Science Tools | Description |
# |---|---|
# | Jupyter Notebook | A web-based interactive environment for writing and running code |
# | GitHub | A code hosting platform for version control and collaboration |
# | Google Colab | A free online Jupyter notebook environment |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python:
#
# * the expression `2 + 2` adds 2 and 2 and returns the result, which is 4.
#
# * and another`2 * 3` multiplies 2 and 3 and returns the result, which is 6.

# %%
# This a simple arithmetic expression to mutiply then add integers

def multiply_and_add():
  num1 = 3
  num2 = 4
  result = num1 * num2 + 5
  return result

print(multiply_and_add())
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60

def minutes_to_hours(minutes):
  hours = minutes / 60
  return hours

print(minutes_to_hours(200))
# Out:
# 3.3333333333333335

# %% [markdown]
# **Objectives:**
#
# * Learn data science languages
# * About libraries
# * Science tools
# * How to use arithmetic expressions in code cells
# * Convert minutes to hours

# %% [markdown]
# ## **Author:** Damien and Skills Lab

# %% [markdown]
# ![image.png](attachment:3ba0d5da-985e-4c09-b763-a9dac3513b63.png)
